# %% [markdown]
# ## Essentials

# %%
drug='ciprofloxacin'

# %%
import numpy as np
import pandas as pd
import networkx as nx


from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.utils import resample
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.base import clone
from sklearn.metrics import roc_auc_score

import statsmodels.api as sm
from statsmodels.stats.multitest import fdrcorrection
from statsmodels.formula.api import ols

import sys
sys.path.append("..")
sys.path.append("../..")
from cluster_analysis import *
# from LOR_calculation import *

import warnings

species='Escherichia_coli'

X_df = pd.read_csv(f'../../data/temp/X_{species}_SxG_filtered_hypo_unknowns_freq5.csv', index_col=0) # filtering

drugs = ['streptomycin',
 'sulfamethoxazole',
 'tetracycline',
 'cefalothin',
 'trimethoprim_sulphamethoxazole',
 'amoxicillin_clavulanic_acid',
 'trimethoprim',
 'amoxicillin',
 'ampicillin',
 'doripenem',
 'levofloxacin',
 'ciprofloxacin']


G=nx.read_graphml('../../data/nets/Escherichia_coli/200_randomized_SVM_0.2unsigned_corr_trimethoprim.graphml')
edge_list = list(G.edges)


pheno_df= pd.read_csv(f'../../metadata/{species}/{species}_{drug}.csv', index_col=0)
y_df=pheno_df
y_df.index = y_df.index.astype('float')

y_df = y_df.sort_index()

y_indices=list(y_df.index)


X_df = X_df.sort_index()
y_df = y_df.sort_index()

y_indices=list(y_df.index)
X_indices=list(X_df.index)

intersection = [i for i in y_indices if i in X_indices]
y_df = y_df.loc[intersection]
X_df = X_df.loc[intersection]

X_df = X_df.sort_index()
y_df = y_df.sort_index() # -- just making sure bcs im paranoid

X = X_df.values
y = y_df.values



labeled_matrix = pd.concat([X_df, y_df], axis=1)
labeled_matrix.shape
# Out:
# (1672, 18876)

# %% [markdown]
# ## Models

# %% [markdown]
# ### formula

# %%
f'{count_errors} removed out of {len(X_pairs)} due to colinearity'
# Out:
# '2412 removed out of 7554 due to colinearity'

# %%
import statsmodels.formula.api as smf
import statsmodels
import warnings

X_pairs = [(i.replace(' ', '_'), j.replace(' ', '_')) for i, j in edge_list]
interaction_labeled_matrix = labeled_matrix.rename(columns={col: col.replace(' ', '_') for col in labeled_matrix.columns})

# formula = f'SIR ~ {a} + {b} + {a}:{b}'

test_pairs = X_pairs[:1]
count_errors=0

warnings.filterwarnings('ignore')

for pair in X_pairs:
    a, b = pair
    print(" --- looking into the edge between", a, "and", b)

    logit_model = smf.logit(formula=f'SIR ~ {a} + {b} + {a}:{b}', data=interaction_labeled_matrix)
    try:
        results = logit_model.fit(disp=0)
    except Exception as e:
        print(f"An error occurred: {e}")
        count_errors+=1
# Out:
#  --- looking into the edge between Cluster_0 and Cluster_20
#  --- looking into the edge between Cluster_0 and Cluster_88
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_153
#  --- looking into the edge between Cluster_0 and Cluster_162
#  --- looking into the edge between Cluster_0 and Cluster_714
#  --- looking into the edge between Cluster_0 and Cluster_797
#  --- looking into the edge between Cluster_0 and Cluster_833
#  --- looking into the edge between Cluster_0 and Cluster_925
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_954
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_1121
#  --- looking into the edge between Cluster_0 and Cluster_1124
#  --- looking into the edge between Cluster_0 and Cluster_2259
#  --- looking into the edge between Cluster_0 and Cluster_2505
#  --- looking into the edge between Cluster_0 and Cluster_2510
#  --- looking into the edge between Cluster_0 and Cluster_2564
#  --- looking into the edge between Cluster_0 and Cluster_2620
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_3085
#  --- looking into the edge between Cluster_0 and Cluster_3205
#  --- looking into the edge between Cluster_0 and Cluster_3612
#  --- looking into the edge between Cluster_0 and Cluster_3627
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_4105
#  --- looking into the edge between Cluster_0 and Cluster_4200
#  --- looking into the edge between Cluster_0 and Cluster_5023
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_5077
#  --- looking into the edge between Cluster_0 and Cluster_5554
#  --- looking into the edge between Cluster_0 and Cluster_5709
#  --- looking into the edge between Cluster_0 and Cluster_6087
#  --- looking into the edge between Cluster_0 and Cluster_6929
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_7052
#  --- looking into the edge between Cluster_0 and Cluster_7457
#  --- looking into the edge between Cluster_0 and Cluster_7535
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_7579
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_7724
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_7961
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_8165
#  --- looking into the edge between Cluster_0 and Cluster_8911
#  --- looking into the edge between Cluster_0 and Cluster_9338
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_9856
#  --- looking into the edge between Cluster_0 and Cluster_10077
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_10175
#  --- looking into the edge between Cluster_0 and Cluster_10829
#  --- looking into the edge between Cluster_0 and Cluster_11116
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_11161
#  --- looking into the edge between Cluster_0 and Cluster_11434
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_11507
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_11569
#  --- looking into the edge between Cluster_0 and Cluster_12018
#  --- looking into the edge between Cluster_0 and Cluster_12367
#  --- looking into the edge between Cluster_0 and Cluster_13284
#  --- looking into the edge between Cluster_0 and Cluster_15695
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_16019
#  --- looking into the edge between Cluster_0 and Cluster_16298
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_17239
#  --- looking into the edge between Cluster_0 and Cluster_18476
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_18556
#  --- looking into the edge between Cluster_0 and Cluster_19172
#  --- looking into the edge between Cluster_0 and Cluster_19477
#  --- looking into the edge between Cluster_0 and Cluster_20322
#  --- looking into the edge between Cluster_0 and Cluster_20676
#  --- looking into the edge between Cluster_0 and Cluster_21235
#  --- looking into the edge between Cluster_0 and Cluster_22905
#  --- looking into the edge between Cluster_0 and Cluster_23182
#  --- looking into the edge between Cluster_0 and Cluster_23659
#  --- looking into the edge between Cluster_0 and Cluster_24859
#  --- looking into the edge between Cluster_0 and Cluster_27630
#  --- looking into the edge between Cluster_0 and Cluster_29724
#  --- looking into the edge between Cluster_0 and Cluster_30572
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_31072
#  --- looking into the edge between Cluster_0 and Cluster_31808
#  --- looking into the edge between Cluster_0 and Cluster_32961
#  --- looking into the edge between Cluster_0 and Cluster_33540
#  --- looking into the edge between Cluster_0 and Cluster_34688
#  --- looking into the edge between Cluster_0 and Cluster_36013
#  --- looking into the edge between Cluster_0 and Cluster_37186
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_39400
#  --- looking into the edge between Cluster_0 and Cluster_40489
#  --- looking into the edge between Cluster_0 and Cluster_40527
#  --- looking into the edge between Cluster_0 and Cluster_42087
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_42677
#  --- looking into the edge between Cluster_0 and Cluster_42908
#  --- looking into the edge between Cluster_0 and Cluster_44699
#  --- looking into the edge between Cluster_0 and Cluster_45838
#  --- looking into the edge between Cluster_0 and Cluster_45971
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_46568
#  --- looking into the edge between Cluster_0 and Cluster_48459
#  --- looking into the edge between Cluster_0 and Cluster_48985
#  --- looking into the edge between Cluster_0 and Cluster_52453
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_52458
#  --- looking into the edge between Cluster_0 and Cluster_53237
#  --- looking into the edge between Cluster_0 and Cluster_53280
#  --- looking into the edge between Cluster_0 and Cluster_54695
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_60592
#  --- looking into the edge between Cluster_0 and Cluster_61533
#  --- looking into the edge between Cluster_0 and Cluster_61877
#  --- looking into the edge between Cluster_0 and Cluster_61930
#  --- looking into the edge between Cluster_0 and Cluster_63797
#  --- looking into the edge between Cluster_0 and Cluster_64239
#  --- looking into the edge between Cluster_0 and Cluster_65446
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_0 and Cluster_66861
#  --- looking into the edge between Cluster_0 and Cluster_67334
#  --- looking into the edge between Cluster_0 and Cluster_69728
#  --- looking into the edge between Cluster_0 and Cluster_70485
#  --- looking into the edge between Cluster_0 and Cluster_70645
#  --- looking into the edge between Cluster_0 and Cluster_72154
#  --- looking into the edge between Cluster_0 and Cluster_80802
#  --- looking into the edge between Cluster_0 and Cluster_81287
#  --- looking into the edge between Cluster_0 and Cluster_84101
#  --- looking into the edge between Cluster_0 and Cluster_84227
#  --- looking into the edge between Cluster_0 and Cluster_84956
#  --- looking into the edge between Cluster_0 and Cluster_88518
#  --- looking into the edge between Cluster_20 and Cluster_57
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_95
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_201
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_208
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_640
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_1158
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_1574
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_1636
#  --- looking into the edge between Cluster_20 and Cluster_2186
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_2582
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_2823
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_2834
#  --- looking into the edge between Cluster_20 and Cluster_3285
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_3352
#  --- looking into the edge between Cluster_20 and Cluster_4200
#  --- looking into the edge between Cluster_20 and Cluster_4530
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_4723
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_4823
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_6129
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_6425
#  --- looking into the edge between Cluster_20 and Cluster_6430
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_6710
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_6833
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_7388
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_7535
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_7814
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_9013
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_9901
#  --- looking into the edge between Cluster_20 and Cluster_10016
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_10018
#  --- looking into the edge between Cluster_20 and Cluster_10782
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_11374
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_14515
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_15418
#  --- looking into the edge between Cluster_20 and Cluster_15533
#  --- looking into the edge between Cluster_20 and Cluster_16353
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_17239
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_20043
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_21204
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_21247
#  --- looking into the edge between Cluster_20 and Cluster_21660
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_23182
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_23485
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_24177
#  --- looking into the edge between Cluster_20 and Cluster_24231
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_24729
#  --- looking into the edge between Cluster_20 and Cluster_25405
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_25606
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_25745
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_26251
#  --- looking into the edge between Cluster_20 and Cluster_26731
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_26806
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_27022
#  --- looking into the edge between Cluster_20 and Cluster_28706
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_30702
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_32422
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_35720
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_37186
#  --- looking into the edge between Cluster_20 and Cluster_38344
#  --- looking into the edge between Cluster_20 and Cluster_39842
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_41568
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_43789
#  --- looking into the edge between Cluster_20 and Cluster_45838
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_46354
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_48448
#  --- looking into the edge between Cluster_20 and Cluster_50855
#  --- looking into the edge between Cluster_20 and Cluster_51889
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_58812
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_58866
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_60283
#  --- looking into the edge between Cluster_20 and Cluster_61533
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_61731
#  --- looking into the edge between Cluster_20 and Cluster_62584
#  --- looking into the edge between Cluster_20 and Cluster_62652
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_63035
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_63408
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_63873
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_64203
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_64630
#  --- looking into the edge between Cluster_20 and Cluster_68066
#  --- looking into the edge between Cluster_20 and Cluster_68761
#  --- looking into the edge between Cluster_20 and Cluster_69242
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_70204
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_73156
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_75356
#  --- looking into the edge between Cluster_20 and Cluster_81477
#  --- looking into the edge between Cluster_20 and Cluster_85917
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_88812
#  --- looking into the edge between Cluster_20 and Cluster_89201
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20 and Cluster_89907
#  --- looking into the edge between Cluster_20 and Cluster_90421
#  --- looking into the edge between Cluster_162 and Cluster_2
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_797 and Cluster_21
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_833 and Cluster_6
#  --- looking into the edge between Cluster_954 and Cluster_23
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_2259 and Cluster_17
#  --- looking into the edge between Cluster_2259 and Cluster_58
#  --- looking into the edge between Cluster_2510 and Cluster_23
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_2564 and Cluster_17
#  --- looking into the edge between Cluster_2564 and Cluster_64
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_2620 and Cluster_6
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_2620 and Cluster_49
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_3085 and Cluster_21
#  --- looking into the edge between Cluster_3085 and Cluster_49
#  --- looking into the edge between Cluster_3085 and Cluster_53
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_3205 and Cluster_21
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_3205 and Cluster_56
#  --- looking into the edge between Cluster_3612 and Cluster_17
#  --- looking into the edge between Cluster_4105 and Cluster_17
#  --- looking into the edge between Cluster_4200 and Cluster_37
#  --- looking into the edge between Cluster_5023 and Cluster_49
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_5023 and Cluster_56
#  --- looking into the edge between Cluster_5077 and Cluster_2
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_5077 and Cluster_56
#  --- looking into the edge between Cluster_6087 and Cluster_2
#  --- looking into the edge between Cluster_6087 and Cluster_17
#  --- looking into the edge between Cluster_6929 and Cluster_2
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_6929 and Cluster_56
#  --- looking into the edge between Cluster_7457 and Cluster_21
#  --- looking into the edge between Cluster_7579 and Cluster_70
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_7724 and Cluster_2
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_7961 and Cluster_2
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_7961 and Cluster_56
#  --- looking into the edge between Cluster_8165 and Cluster_2
#  --- looking into the edge between Cluster_8165 and Cluster_6
#  --- looking into the edge between Cluster_8911 and Cluster_2
#  --- looking into the edge between Cluster_8911 and Cluster_56
#  --- looking into the edge between Cluster_9338 and Cluster_2
#  --- looking into the edge between Cluster_9856 and Cluster_21
#  --- looking into the edge between Cluster_9856 and Cluster_64
#  --- looking into the edge between Cluster_10077 and Cluster_2
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_10077 and Cluster_56
#  --- looking into the edge between Cluster_11507 and Cluster_2
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_11507 and Cluster_6
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_11569 and Cluster_49
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_12367 and Cluster_21
#  --- looking into the edge between Cluster_12367 and Cluster_64
#  --- looking into the edge between Cluster_13284 and Cluster_56
#  --- looking into the edge between Cluster_15695 and Cluster_58
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_17239 and Cluster_17
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_17239 and Cluster_57
#  --- looking into the edge between Cluster_18476 and Cluster_2
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_18556 and Cluster_2
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_20676 and Cluster_2
#  --- looking into the edge between Cluster_20676 and Cluster_58
#  --- looking into the edge between Cluster_21235 and Cluster_29
#  --- looking into the edge between Cluster_23182 and Cluster_17
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_23182 and Cluster_21
#  --- looking into the edge between Cluster_27630 and Cluster_58
#  --- looking into the edge between Cluster_29724 and Cluster_72
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_31808 and Cluster_2
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_31808 and Cluster_56
#  --- looking into the edge between Cluster_37186 and Cluster_57
#  --- looking into the edge between Cluster_40489 and Cluster_58
#  --- looking into the edge between Cluster_42087 and Cluster_2
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_42087 and Cluster_56
#  --- looking into the edge between Cluster_45838 and Cluster_21
#  --- looking into the edge between Cluster_48985 and Cluster_4
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_48985 and Cluster_21
#  --- looking into the edge between Cluster_48985 and Cluster_29
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_53280 and Cluster_29
#  --- looking into the edge between Cluster_60592 and Cluster_58
#  --- looking into the edge between Cluster_61533 and Cluster_4
#  --- looking into the edge between Cluster_61533 and Cluster_21
#  --- looking into the edge between Cluster_61877 and Cluster_21
#  --- looking into the edge between Cluster_61930 and Cluster_23
#  --- looking into the edge between Cluster_61930 and Cluster_48
#  --- looking into the edge between Cluster_64239 and Cluster_49
#  --- looking into the edge between Cluster_65446 and Cluster_70
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_72 and Cluster_43427
#  --- looking into the edge between Cluster_72 and Cluster_44215
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_72 and Cluster_44657
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_72 and Cluster_45848
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_72 and Cluster_46078
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_72 and Cluster_46570
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_72 and Cluster_47210
#  --- looking into the edge between Cluster_72 and Cluster_48456
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_72 and Cluster_48938
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_72 and Cluster_49244
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_72 and Cluster_49521
#  --- looking into the edge between Cluster_72 and Cluster_50007
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_72 and Cluster_50118
#  --- looking into the edge between Cluster_72 and Cluster_50957
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_72 and Cluster_51091
#  --- looking into the edge between Cluster_72 and Cluster_51093
#  --- looking into the edge between Cluster_72 and Cluster_51569
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_72 and Cluster_52155
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_72 and Cluster_52427
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_72 and Cluster_53319
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_72 and Cluster_54890
#  --- looking into the edge between Cluster_72 and Cluster_55170
# An error occurred: Singular matrix
#  --- looking into the edge between Cluster_72 and Cluster_55798
# An error occurred: Singular matrix

# %%
X_pairs = [(i.replace(' ', '_'), j.replace(' ', '_')) for i, j in edge_list]
interaction_labeled_matrix = labeled_matrix.rename(columns={col: col.replace(' ', '_') for col in labeled_matrix.columns})

# formula = f'SIR ~ {a} + {b} + {a}:{b}'

test_pairs = X_pairs[:1]
count_errors=0

warnings.filterwarnings('ignore')

for pair in X_pairs:
    a, b = pair
    print(" --- looking into the edge between", a, "and", b)

    logit_model = smf.logit(formula=f'SIR ~ {a} + {b} + {a}:{b}', data=interaction_labeled_matrix)
    try:
        results = logit_model.fit(disp=0)
    except Exception as e:
        print(f"An error occurred: {e}")
        count_errors+=1

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    SIR   No. Observations:                 1672
# Model:                          Logit   Df Residuals:                     1668
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 01 May 2024   Pseudo R-squ.:                 0.02221
# Time:                        15:37:47   Log-Likelihood:                -946.23
# converged:                      False   LL-Null:                       -967.72
# Covariance Type:            nonrobust   LLR p-value:                 2.467e-09
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               -1.0587      0.059    -17.852      0.000      -1.175      -0.942
# Cluster_0               -0.0736      0.193     -0.380      0.704      -0.453       0.306
# Cluster_20              15.8568   1634.466      0.010      0.992   -3187.639    3219.352
# Cluster_0:Cluster_20   -12.7787   1634.467     -0.008      0.994   -3216.274    3190.717
# ========================================================================================
# """

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    SIR   No. Observations:                 1672
# Model:                          Logit   Df Residuals:                     1668
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 01 May 2024   Pseudo R-squ.:                 0.02221
# Time:                        15:36:25   Log-Likelihood:                -946.23
# converged:                      False   LL-Null:                       -967.72
# Covariance Type:            nonrobust   LLR p-value:                 2.467e-09
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               -1.0587      0.059    -17.852      0.000      -1.175      -0.942
# Cluster_0               -0.0736      0.193     -0.380      0.704      -0.453       0.306
# Cluster_20              15.8568   1634.466      0.010      0.992   -3187.639    3219.352
# Cluster_0:Cluster_20   -12.7787   1634.467     -0.008      0.994   -3216.274    3190.717
# ========================================================================================
# """

# %% [markdown]
# ### vanilla

# %%
X_pairs=edge_list
error_test=[("Cluster 0", "Cluster 20")]

p_values_list = []

for pair in error_test:
    a, b = pair
    print(" --- looking into the edge between", a, "and", b)

    X_selected = X_df.loc[:, [a, b]]

    print(X_selected.shape)

    X_selected = sm.add_constant(X_selected)

    X_selected['interaction'] = X_selected.iloc[:, a] * X_selected.iloc[:, b]

    try:
        with warnings.catch_warnings():
            warnings.filterwarnings("ignore")
            logit_model = sm.Logit(y, X_selected)
            result = logit_model.fit()
            p_values_list.append(result.pvalues['interaction'])

    except:
        print('singular matrix; deleted')
